# %%
#ESTRUCTURAS DE DATOS
listas=[1,2,3,5]
#tuplas=
#diccionario=
listas[3]
type(listas)
len(listas)
# Out:
# 4

# %%
#crear constantes que no se pueden modificar
tuplas=(2,3,5)
conjuntos ={1,2,3,1}
list(set(conjuntos))
# Out:
# [1, 2, 3]

# %%
#OPERADORES
#OPERADORES ARITMETICO
6+5
6-4
6*5
2**2
6%2
#OPERADOR DE ASIGNACION
X = 6
# Out:
# 0
